# %%
# expr = "(& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (| (! var_18) (! var_15)) (| (! var_14) (! var_9))) (| (| (! var_19) var_37) var_12)) (! var_39)) (| (! var_20) var_18)) (| (| (! var_8) var_16) (! var_24))) (| (! var_29) (! var_39))) (| (! var_2) var_19)) var_15) (| (| (! var_37) var_19) (! var_6))) (| var_25 (! var_23))) (| (| (! var_17) var_40) var_21)) (| (| (! var_23) var_35) var_24)) (| (! var_30) (! var_28))) var_15) (| (| (! var_37) var_19) var_6)) (| (! var_3) (! var_11))) (| (! var_35) (! var_3))) (| (| (! var_29) var_39) var_22)) (| (! var_27) (! var_10))) (| var_28 (! var_8))) (| (! var_4) var_39)) (| var_10 var_26)) (| (| var_22 var_14) var_15)) (! var_13)) (| (| var_36 var_28) (! var_35))) (| (| (! var_8) var_16) var_24)) (| (| (! var_7) var_3) (! var_40))) (| (| var_22 var_14) var_15)) (! var_13)) (| (| (! var_8) var_16) var_24)) (| (| (! var_19) var_37) var_12)) (| var_10 (! var_26))) (| (! var_20) (! var_18))) (| (! var_8) (! var_16))) (| (| (! var_3) var_11) (! var_23))) (| (! var_16) var_37)) (| (! var_38) (! var_11))) (| (| (! var_31) var_13) var_14)) (| (! var_33) var_19)) (| (| (! var_14) var_9) (! var_29))) (| var_6 var_16)) (| (| var_36 var_28) var_35)) (| (! var_19) (! var_37))) (| (! var_5) var_6)) (| var_10 var_26)) (| (| (! var_3) var_11) var_23)) (| (| var_26 var_37) (! var_16))) (| (| var_22 var_14) (! var_15))) (| (| var_25 var_23) var_38)) (| var_36 (! var_28))) (| (! var_35) var_3)) (| (| (! var_34) var_35) (! var_37))) (| (! var_5) (! var_6))) (| (! var_33) (! var_19))) (| (| (! var_17) var_40) var_21)) (| (| (! var_30) var_28) var_4)) (| (| (! var_34) var_35) var_37)) (| (| var_28 var_8) var_29)) (! var_21)) (| (| (! var_18) var_15) var_39)) var_40) (| (| (! var_3) var_11) var_23)) (| (! var_17) (! var_40))) (| (! var_35) var_3)) (| (! var_33) var_19)) (| (| var_25 var_23) (! var_38))) (| (! var_27) var_10)) (| (| var_36 var_28) var_35)) (| (| (! var_7) var_3) var_40)) (| (! var_11) var_35)) (| var_6 var_16)) (| (| (! var_30) var_28) var_4)) (| (! var_11) (! var_35))) (| (! var_32) var_19)) (| (! var_37) (! var_19))) (| var_26 (! var_37))) (| (| (! var_30) var_28) (! var_4))) (! var_21)) (| (! var_20) var_18)) (| (! var_9) var_31)) (| (| var_28 var_8) var_29)) (| (| (! var_31) var_13) (! var_14))) (| (| (! var_24) var_32) var_35)) (| var_12 var_16)) (| (| (! var_29) var_39) var_22)) (| (| (! var_14) var_9) var_29)) (! var_39)) (| (! var_4) (! var_39))) (| (| (! var_37) var_19) var_6)) (| (! var_23) (! var_35))) (| (| (! var_29) var_39) (! var_22))) (| (! var_5) var_6)) var_40) (| (| var_25 var_23) var_38)) (| (! var_2) var_19)) (| var_12 var_16)) (| (| (! var_23) var_35) var_24)) (| (! var_31) (! var_13))) (| (! var_34) (! var_35))) (| (! var_32) var_19)) (| (| (! var_24) var_32) var_35)) (| (| var_26 var_37) var_16)) (| (! var_38) var_11)) (| (! var_16) var_37)) (| (| (! var_7) var_3) var_40)) (| (! var_4) var_39)) (| (! var_7) (! var_3))) (| (| (! var_24) var_32) (! var_35))) (| (| (! var_34) var_35) var_37)) (| (! var_11) var_35)) var_1) (| (! var_27) var_10)) (| (| (! var_23) var_35) (! var_24))) (| (| (! var_18) var_15) (! var_39))) (| (| (! var_19) var_37) (! var_12))) (| (| var_26 var_37) var_16)) (| var_6 (! var_16))) (| (| (! var_17) var_40) (! var_21))) (| (! var_9) (! var_31))) (| (! var_32) (! var_19))) (| (! var_38) var_11)) (| (! var_9) var_31)) (| (| (! var_14) var_9) var_29)) (| (| (! var_18) var_15) var_39)) (| var_12 (! var_16))) (| (! var_16) (! var_37))) (| var_22 (! var_14))) (| (| var_28 var_8) (! var_29))) var_1) (| (! var_24) (! var_32))) (| (! var_2) (! var_19))) (| (| (! var_31) var_13) var_14))"

# expr = "(& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (| (| (! var_3) var_36) var_7) (| (| (! var_3) (! var_42)) (! var_48))) (| (| (! var_49) (! var_47)) (! var_41))) (| (| var_8 (! var_40)) var_17)) (| (| (! var_21) (! var_31)) (! var_39))) (| (| var_36 (! var_22)) var_49)) (| (| var_27 var_38) var_14)) (| (| var_15 (! var_18)) var_6)) (| (| var_6 var_7) (! var_43))) (| (| var_34 (! var_7)) var_23)) (| (| var_2 var_14) (! var_13))) (| (| var_2 var_47) (! var_42))) (| (| (! var_33) (! var_35)) var_3)) (| (| var_44 var_40) var_49)) (| (| var_50 var_36) var_31)) (| (| (! var_36) (! var_3)) (! var_37))) (| (| var_26 (! var_29)) var_43)) (| (| var_15 var_29) (! var_45))) (| (| var_24 (! var_11)) var_18)) (| (| (! var_47) (! var_26)) var_6)) (| (| (! var_50) (! var_33)) (! var_10))) (| (| var_32 var_6) var_16)) (| (| (! var_34) var_37) var_41)) (| (| var_7 (! var_28)) (! var_17))) (| (| (! var_44) var_46) var_19)) (| (| var_7 var_22) (! var_48))) (| (| var_3 var_39) var_34)) (| (| var_31 var_46) (! var_43))) (| (| (! var_27) var_32) var_23)) (| (| var_37 (! var_50)) (! var_18))) (| (| var_20 var_5) var_11)) (| (| (! var_45) (! var_24)) var_6)) (| (| (! var_34) (! var_23)) (! var_14))) (| (| (! var_22) var_21) var_20)) (| (| (! var_17) var_50) var_24)) (| (| (! var_25) (! var_24)) (! var_27))) (| (| var_3 var_35) var_21)) (| (| (! var_26) var_47) (! var_36))) (| (| (! var_28) (! var_45)) var_49)) (| (| (! var_21) (! var_6)) var_12)) (| (| (! var_17) (! var_15)) (! var_39))) (| (| var_41 var_2) (! var_14))) (| (| var_25 var_36) (! var_23))) (| (| (! var_39) (! var_3)) (! var_40))) (| (| var_50 var_20) var_35)) (| (| var_27 var_31) (! var_39))) (| (| var_45 (! var_15)) (! var_40))) (| (| var_34 var_50) var_35)) (| (| (! var_1) (! var_48)) var_12)) (| (| var_18 (! var_35)) (! var_30))) (| (| var_27 (! var_24)) (! var_25))) (| (| (! var_4) (! var_33)) (! var_12))) (| (| (! var_43) (! var_24)) (! var_37))) (| (| (! var_37) var_31) (! var_44))) (| (| (! var_9) (! var_38)) var_14)) (| (| var_33 (! var_16)) var_34)) (| (| var_4 (! var_35)) (! var_5))) (| (| (! var_3) (! var_21)) (! var_19))) (| (| (! var_35) (! var_36)) (! var_29))) (| (| var_7 (! var_43)) var_36)) (| (| var_30 var_14) var_41)) (| (| (! var_35) (! var_24)) (! var_7))) (| (| var_35 (! var_42)) var_6)) (| (| (! var_1) (! var_15)) var_39)) (| (| var_27 var_49) (! var_16))) (| (| (! var_37) var_49) (! var_10))) (| (| var_50 (! var_46)) (! var_3))) (| (| (! var_41) var_20) var_34)) (| (| (! var_1) var_23) var_28)) (| (| (! var_12) (! var_30)) (! var_20))) (| (| (! var_24) var_29) (! var_37))) (| (| var_12 var_5) (! var_44))) (| (| (! var_6) (! var_2)) var_48)) (| (| (! var_2) (! var_49)) (! var_43))) (| (| var_1 (! var_50)) var_24)) (| (| (! var_7) (! var_50)) (! var_44))) (| (| (! var_41) var_43) var_4)) (| (| var_13 var_15) (! var_11))) (| (| (! var_3) (! var_11)) var_23)) (| (| var_33 var_48) var_41)) (| (| var_9 var_23) (! var_49))) (| (| (! var_43) var_47) var_1)) (| (| (! var_40) var_16) (! var_29))) (| (| var_30 var_19) var_3)) (| (| var_19 (! var_34)) var_48)) (| (| (! var_16) (! var_44)) var_14)) (| (| var_38 (! var_45)) (! var_12))) (| (| (! var_4) (! var_14)) (! var_31))) (| (| (! var_48) var_35) (! var_1))) (| (| var_45 (! var_13)) var_19)) (| (| var_9 var_42) (! var_7))) (| (| (! var_1) (! var_15)) var_8)) (| (| (! var_13) (! var_44)) (! var_14))) (| (| (! var_43) (! var_37)) (! var_31))) (| (| (! var_27) (! var_29)) var_47)) (| (| var_7 var_4) var_17)) (| (| var_7 var_10) var_35)) (| (| (! var_25) var_20) var_17)) (| (| var_35 (! var_5)) (! var_42))) (| (| (! var_50) var_24) (! var_5))) (| (| (! var_21) (! var_26)) var_2)) (| (| (! var_8) var_45) (! var_21))) (| (| (! var_16) var_33) var_49)) (| (| (! var_38) var_6) var_16)) (| (| var_5 var_21) var_37)) (| (| var_8 var_38) var_31)) (| (| (! var_21) var_33) var_14)) (| (| var_20 var_40) (! var_5))) (| (| (! var_29) (! var_9)) var_31)) (| (| (! var_7) var_42) (! var_22))) (| (| (! var_48) var_8) var_26)) (| (| var_48 (! var_38)) var_33)) (| (| (! var_34) var_49) var_46)) (| (| (! var_14) (! var_46)) var_25)) (| (| (! var_46) var_4) var_18)) (| (| var_36 (! var_12)) (! var_31))) (| (| var_12 (! var_18)) var_14)) (| (| (! var_7) var_46) (! var_16))) (| (| var_9 (! var_8)) var_7)) (| (| var_49 (! var_42)) (! var_22))) (| (| var_22 (! var_15)) var_38)) (| (| var_34 (! var_41)) var_47)) (| (| var_22 (! var_26)) var_32)) (| (| (! var_25) (! var_45)) (! var_21))) (| (| (! var_26) var_32) (! var_11))) (| (| var_15 var_26) (! var_25))) (| (| (! var_1) var_46) var_25)) (| (| (! var_14) (! var_31)) var_30)) (| (| (! var_9) (! var_22)) var_12)) (| (| (! var_18) var_26) (! var_35))) (| (| (! var_16) (! var_32)) (! var_21))) (| (| var_31 (! var_49)) (! var_21))) (| (| var_11 var_9) var_41)) (| (| (! var_13) (! var_30)) var_19)) (| (| (! var_10) var_4) var_6)) (| (| (! var_4) var_3) (! var_22))) (| (| (! var_25) (! var_50)) (! var_18))) (| (| (! var_40) var_4) var_9)) (| (| var_37 var_20) var_46)) (| (| (! var_27) var_22) (! var_29))) (| (| var_34 var_14) var_3)) (| (| var_3 (! var_31)) var_20)) (| (| (! var_50) var_2) (! var_26))) (| (| var_17 (! var_29)) var_38)) (| (| (! var_49) var_12) (! var_41))) (| (| var_15 (! var_35)) (! var_43))) (| (| (! var_22) (! var_23)) (! var_49))) (| (| (! var_9) var_33) var_48)) (| (| var_26 var_29) var_35)) (| (| var_27 (! var_50)) var_37)) (| (| (! var_7) var_46) (! var_43))) (| (| (! var_46) (! var_37)) (! var_8))) (| (| (! var_40) var_36) (! var_24))) (| (| (! var_44) var_46) var_15)) (| (| (! var_3) var_36) (! var_16))) (| (| (! var_48) var_9) var_43)) (| (| (! var_25) (! var_4)) var_44)) (| (| (! var_22) var_37) (! var_7))) (| (| (! var_31) (! var_17)) (! var_22))) (| (| (! var_11) (! var_48)) var_17)) (| (| var_23 var_34) (! var_28))) (| (| var_23 (! var_48)) (! var_39))) (| (| (! var_37) (! var_1)) (! var_23))) (| (| (! var_19) var_27) var_14)) (| (| (! var_22) var_33) (! var_6))) (| (| (! var_6) (! var_32)) (! var_26))) (| (| var_18 (! var_20)) (! var_46))) (| (| var_43 var_22) var_27)) (| (| (! var_13) var_34) var_49)) (| (| (! var_35) (! var_46)) var_3)) (| (| var_32 var_39) (! var_43))) (| (| var_6 (! var_39)) (! var_9))) (| (| var_27 var_39) (! var_16))) (| (| var_25 (! var_17)) (! var_15))) (| (| (! var_43) var_27) var_34)) (| (| (! var_6) var_49) var_5)) (| (| (! var_38) var_11) var_14)) (| (| var_40 (! var_38)) var_47)) (| (| var_37 (! var_14)) var_17)) (| (| var_39 var_29) var_36)) (| (| (! var_39) (! var_28)) var_1)) (| (| (! var_18) var_14) (! var_16))) (| (| (! var_40) var_50) var_15)) (| (| var_37 (! var_42)) var_18)) (| (| (! var_13) var_31) var_33)) (| (| var_2 (! var_42)) var_33)) (| (| var_8 (! var_3)) (! var_22))) (| (| var_1 var_23) (! var_31))) (| (| (! var_20) (! var_45)) var_26)) (| (| var_42 var_11) var_49)) (| (| var_29 var_11) (! var_43))) (| (| (! var_20) (! var_21)) var_30)) (| (| var_23 var_45) (! var_35))) (| (| var_38 (! var_30)) (! var_14))) (| (| (! var_9) var_48) (! var_29))) (| (| var_11 (! var_18)) (! var_23))) (| (| (! var_41) (! var_1)) (! var_29))) (| (| var_5 var_41) var_26)) (| (| var_44 (! var_30)) (! var_7))) (| (| var_38 (! var_6)) (! var_41))) (| (| var_46 var_48) (! var_15))) (| (| (! var_18) (! var_10)) (! var_47))) (| (| var_38 var_46) (! var_32))) (| (| (! var_32) var_46) var_12)) (| (| var_31 var_40) var_14)) (| (| (! var_18) var_2) var_49)) (| (| var_28 (! var_38)) var_27)) (| (| (! var_16) (! var_21)) var_14)) (| (| (! var_29) var_15) var_12)) (| (| var_49 var_34) var_5)) (| (| var_14 var_22) (! var_12))) (| (| var_30 var_33) var_20)) (| (| (! var_24) var_22) var_25)) (| (| var_4 (! var_48)) (! var_23))) (| (| (! var_30) (! var_36)) var_9)) (| (| var_44 var_12) (! var_35))) (| (| var_38 var_3) (! var_21))) (| (| (! var_11) var_33) var_49))"

# expr = "(& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (! (= var_11 var_12)) (! (= var_11 var_13))) (! (= var_11 var_14))) (! (= var_11 var_15))) (! (= var_11 var_16))) (! (= var_11 var_17))) (! (= var_11 var_18))) (! (= var_11 var_19))) (! (= var_11 var_21))) (! (= var_11 var_22))) (! (= var_11 var_23))) (! (= var_11 var_31))) (! (= var_11 var_32))) (! (= var_11 var_33))) (! (= var_11 var_41))) (! (= var_11 var_51))) (! (= var_11 var_61))) (! (= var_11 var_71))) (! (= var_11 var_81))) (! (= var_11 var_91))) (! (= var_12 var_13))) (! (= var_12 var_14))) (! (= var_12 var_15))) (! (= var_12 var_16))) (! (= var_12 var_17))) (! (= var_12 var_18))) (! (= var_12 var_19))) (! (= var_12 var_21))) (! (= var_12 var_22))) (! (= var_12 var_23))) (! (= var_12 var_31))) (! (= var_12 var_32))) (! (= var_12 var_33))) (! (= var_12 var_42))) (! (= var_12 var_52))) (! (= var_12 var_62))) (! (= var_12 var_72))) (! (= var_12 var_82))) (! (= var_12 var_92))) (! (= var_13 var_14))) (! (= var_13 var_15))) (! (= var_13 var_16))) (! (= var_13 var_17))) (! (= var_13 var_18))) (! (= var_13 var_19))) (! (= var_13 var_21))) (! (= var_13 var_22))) (! (= var_13 var_23))) (! (= var_13 var_31))) (! (= var_13 var_32))) (! (= var_13 var_33))) (! (= var_13 var_43))) (! (= var_13 var_53))) (! (= var_13 var_63))) (! (= var_13 var_73))) (! (= var_13 var_83))) (! (= var_13 var_93))) (! (= var_14 var_15))) (! (= var_14 var_16))) (! (= var_14 var_17))) (! (= var_14 var_18))) (! (= var_14 var_19))) (! (= var_14 var_24))) (! (= var_14 var_25))) (! (= var_14 var_26))) (! (= var_14 var_34))) (! (= var_14 var_35))) (! (= var_14 var_36))) (! (= var_14 var_44))) (! (= var_14 var_54))) (! (= var_14 var_64))) (! (= var_14 var_74))) (! (= var_14 var_84))) (! (= var_14 var_94))) (! (= var_15 var_16))) (! (= var_15 var_17))) (! (= var_15 var_18))) (! (= var_15 var_19))) (! (= var_15 var_24))) (! (= var_15 var_25))) (! (= var_15 var_26))) (! (= var_15 var_34))) (! (= var_15 var_35))) (! (= var_15 var_36))) (! (= var_15 var_45))) (! (= var_15 var_55))) (! (= var_15 var_65))) (! (= var_15 var_75))) (! (= var_15 var_85))) (! (= var_15 var_95))) (! (= var_16 var_17))) (! (= var_16 var_18))) (! (= var_16 var_19))) (! (= var_16 var_24))) (! (= var_16 var_25))) (! (= var_16 var_26))) (! (= var_16 var_34))) (! (= var_16 var_35))) (! (= var_16 var_36))) (! (= var_16 var_46))) (! (= var_16 var_56))) (! (= var_16 var_66))) (! (= var_16 var_76))) (! (= var_16 var_86))) (! (= var_16 var_96))) (! (= var_17 var_18))) (! (= var_17 var_19))) (! (= var_17 var_27))) (! (= var_17 var_28))) (! (= var_17 var_29))) (! (= var_17 var_37))) (! (= var_17 var_38))) (! (= var_17 var_39))) (! (= var_17 var_47))) (! (= var_17 var_57))) (! (= var_17 var_67))) (! (= var_17 var_77))) (! (= var_17 var_87))) (! (= var_17 var_97))) (! (= var_18 var_19))) (! (= var_18 var_27))) (! (= var_18 var_28))) (! (= var_18 var_29))) (! (= var_18 var_37))) (! (= var_18 var_38))) (! (= var_18 var_39))) (! (= var_18 var_48))) (! (= var_18 var_58))) (! (= var_18 var_68))) (! (= var_18 var_78))) (! (= var_18 var_88))) (! (= var_18 var_98))) (! (= var_19 var_27))) (! (= var_19 var_28))) (! (= var_19 var_29))) (! (= var_19 var_37))) (! (= var_19 var_38))) (! (= var_19 var_39))) (! (= var_19 var_49))) (! (= var_19 var_59))) (! (= var_19 var_69))) (! (= var_19 var_79))) (! (= var_19 var_89))) (! (= var_19 var_99))) (! (= var_21 var_22))) (! (= var_21 var_23))) (! (= var_21 var_24))) (! (= var_21 var_25))) (! (= var_21 var_26))) (! (= var_21 var_27))) (! (= var_21 var_28))) (! (= var_21 var_29))) (! (= var_21 var_31))) (! (= var_21 var_32))) (! (= var_21 var_33))) (! (= var_21 var_41))) (! (= var_21 var_51))) (! (= var_21 var_61))) (! (= var_21 var_71))) (! (= var_21 var_81))) (! (= var_21 var_91))) (! (= var_22 var_23))) (! (= var_22 var_24))) (! (= var_22 var_25))) (! (= var_22 var_26))) (! (= var_22 var_27))) (! (= var_22 var_28))) (! (= var_22 var_29))) (! (= var_22 var_31))) (! (= var_22 var_32))) (! (= var_22 var_33))) (! (= var_22 var_42))) (! (= var_22 var_52))) (! (= var_22 var_62))) (! (= var_22 var_72))) (! (= var_22 var_82))) (! (= var_22 var_92))) (! (= var_23 var_24))) (! (= var_23 var_25))) (! (= var_23 var_26))) (! (= var_23 var_27))) (! (= var_23 var_28))) (! (= var_23 var_29))) (! (= var_23 var_31))) (! (= var_23 var_32))) (! (= var_23 var_33))) (! (= var_23 var_43))) (! (= var_23 var_53))) (! (= var_23 var_63))) (! (= var_23 var_73))) (! (= var_23 var_83))) (! (= var_23 var_93))) (! (= var_24 var_25))) (! (= var_24 var_26))) (! (= var_24 var_27))) (! (= var_24 var_28))) (! (= var_24 var_29))) (! (= var_24 var_34))) (! (= var_24 var_35))) (! (= var_24 var_36))) (! (= var_24 var_44))) (! (= var_24 var_54))) (! (= var_24 var_64))) (! (= var_24 var_74))) (! (= var_24 var_84))) (! (= var_24 var_94))) (! (= var_25 var_26))) (! (= var_25 var_27))) (! (= var_25 var_28))) (! (= var_25 var_29))) (! (= var_25 var_34))) (! (= var_25 var_35))) (! (= var_25 var_36))) (! (= var_25 var_45))) (! (= var_25 var_55))) (! (= var_25 var_65))) (! (= var_25 var_75))) (! (= var_25 var_85))) (! (= var_25 var_95))) (! (= var_26 var_27))) (! (= var_26 var_28))) (! (= var_26 var_29))) (! (= var_26 var_34))) (! (= var_26 var_35))) (! (= var_26 var_36))) (! (= var_26 var_46))) (! (= var_26 var_56))) (! (= var_26 var_66))) (! (= var_26 var_76))) (! (= var_26 var_86))) (! (= var_26 var_96))) (! (= var_27 var_28))) (! (= var_27 var_29))) (! (= var_27 var_37))) (! (= var_27 var_38))) (! (= var_27 var_39))) (! (= var_27 var_47))) (! (= var_27 var_57))) (! (= var_27 var_67))) (! (= var_27 var_77))) (! (= var_27 var_87))) (! (= var_27 var_97))) (! (= var_28 var_29))) (! (= var_28 var_37))) (! (= var_28 var_38))) (! (= var_28 var_39))) (! (= var_28 var_48))) (! (= var_28 var_58))) (! (= var_28 var_68))) (! (= var_28 var_78))) (! (= var_28 var_88))) (! (= var_28 var_98))) (! (= var_29 var_37))) (! (= var_29 var_38))) (! (= var_29 var_39))) (! (= var_29 var_49))) (! (= var_29 var_59))) (! (= var_29 var_69))) (! (= var_29 var_79))) (! (= var_29 var_89))) (! (= var_29 var_99))) (! (= var_31 var_32))) (! (= var_31 var_33))) (! (= var_31 var_34))) (! (= var_31 var_35))) (! (= var_31 var_36))) (! (= var_31 var_37))) (! (= var_31 var_38))) (! (= var_31 var_39))) (! (= var_31 var_41))) (! (= var_31 var_51))) (! (= var_31 var_61))) (! (= var_31 var_71))) (! (= var_31 var_81))) (! (= var_31 var_91))) (! (= var_32 var_33))) (! (= var_32 var_34))) (! (= var_32 var_35))) (! (= var_32 var_36))) (! (= var_32 var_37))) (! (= var_32 var_38))) (! (= var_32 var_39))) (! (= var_32 var_42))) (! (= var_32 var_52))) (! (= var_32 var_62))) (! (= var_32 var_72))) (! (= var_32 var_82))) (! (= var_32 var_92))) (! (= var_33 var_34))) (! (= var_33 var_35))) (! (= var_33 var_36))) (! (= var_33 var_37))) (! (= var_33 var_38))) (! (= var_33 var_39))) (! (= var_33 var_43))) (! (= var_33 var_53))) (! (= var_33 var_63))) (! (= var_33 var_73))) (! (= var_33 var_83))) (! (= var_33 var_93))) (! (= var_34 var_35))) (! (= var_34 var_36))) (! (= var_34 var_37))) (! (= var_34 var_38))) (! (= var_34 var_39))) (! (= var_34 var_44))) (! (= var_34 var_54))) (! (= var_34 var_64))) (! (= var_34 var_74))) (! (= var_34 var_84))) (! (= var_34 var_94))) (! (= var_35 var_36))) (! (= var_35 var_37))) (! (= var_35 var_38))) (! (= var_35 var_39))) (! (= var_35 var_45))) (! (= var_35 var_55))) (! (= var_35 var_65))) (! (= var_35 var_75))) (! (= var_35 var_85))) (! (= var_35 var_95))) (! (= var_36 var_37))) (! (= var_36 var_38))) (! (= var_36 var_39))) (! (= var_36 var_46))) (! (= var_36 var_56))) (! (= var_36 var_66))) (! (= var_36 var_76))) (! (= var_36 var_86))) (! (= var_36 var_96))) (! (= var_37 var_38))) (! (= var_37 var_39))) (! (= var_37 var_47))) (! (= var_37 var_57))) (! (= var_37 var_67))) (! (= var_37 var_77))) (! (= var_37 var_87))) (! (= var_37 var_97))) (! (= var_38 var_39))) (! (= var_38 var_48))) (! (= var_38 var_58))) (! (= var_38 var_68))) (! (= var_38 var_78))) (! (= var_38 var_88))) (! (= var_38 var_98))) (! (= var_39 var_49))) (! (= var_39 var_59))) (! (= var_39 var_69))) (! (= var_39 var_79))) (! (= var_39 var_89))) (! (= var_39 var_99))) (! (= var_41 var_42))) (! (= var_41 var_43))) (! (= var_41 var_44))) (! (= var_41 var_45))) (! (= var_41 var_46))) (! (= var_41 var_47))) (! (= var_41 var_48))) (! (= var_41 var_49))) (! (= var_41 var_51))) (! (= var_41 var_52))) (! (= var_41 var_53))) (! (= var_41 var_61))) (! (= var_41 var_62))) (! (= var_41 var_63))) (! (= var_41 var_71))) (! (= var_41 var_81))) (! (= var_41 var_91))) (! (= var_42 var_43))) (! (= var_42 var_44))) (! (= var_42 var_45))) (! (= var_42 var_46))) (! (= var_42 var_47))) (! (= var_42 var_48))) (! (= var_42 var_49))) (! (= var_42 var_51))) (! (= var_42 var_52))) (! (= var_42 var_53))) (! (= var_42 var_61))) (! (= var_42 var_62))) (! (= var_42 var_63))) (! (= var_42 var_72))) (! (= var_42 var_82))) (! (= var_42 var_92))) (! (= var_43 var_44))) (! (= var_43 var_45))) (! (= var_43 var_46))) (! (= var_43 var_47))) (! (= var_43 var_48))) (! (= var_43 var_49))) (! (= var_43 var_51))) (! (= var_43 var_52))) (! (= var_43 var_53))) (! (= var_43 var_61))) (! (= var_43 var_62))) (! (= var_43 var_63))) (! (= var_43 var_73))) (! (= var_43 var_83))) (! (= var_43 var_93))) (! (= var_44 var_45))) (! (= var_44 var_46))) (! (= var_44 var_47))) (! (= var_44 var_48))) (! (= var_44 var_49))) (! (= var_44 var_54))) (! (= var_44 var_55))) (! (= var_44 var_56))) (! (= var_44 var_64))) (! (= var_44 var_65))) (! (= var_44 var_66))) (! (= var_44 var_74))) (! (= var_44 var_84))) (! (= var_44 var_94))) (! (= var_45 var_46))) (! (= var_45 var_47))) (! (= var_45 var_48))) (! (= var_45 var_49))) (! (= var_45 var_54))) (! (= var_45 var_55))) (! (= var_45 var_56))) (! (= var_45 var_64))) (! (= var_45 var_65))) (! (= var_45 var_66))) (! (= var_45 var_75))) (! (= var_45 var_85))) (! (= var_45 var_95))) (! (= var_46 var_47))) (! (= var_46 var_48))) (! (= var_46 var_49))) (! (= var_46 var_54))) (! (= var_46 var_55))) (! (= var_46 var_56))) (! (= var_46 var_64))) (! (= var_46 var_65))) (! (= var_46 var_66))) (! (= var_46 var_76))) (! (= var_46 var_86))) (! (= var_46 var_96))) (! (= var_47 var_48))) (! (= var_47 var_49))) (! (= var_47 var_57))) (! (= var_47 var_58))) (! (= var_47 var_59))) (! (= var_47 var_67))) (! (= var_47 var_68))) (! (= var_47 var_69))) (! (= var_47 var_77))) (! (= var_47 var_87))) (! (= var_47 var_97))) (! (= var_48 var_49))) (! (= var_48 var_57))) (! (= var_48 var_58))) (! (= var_48 var_59))) (! (= var_48 var_67))) (! (= var_48 var_68))) (! (= var_48 var_69))) (! (= var_48 var_78))) (! (= var_48 var_88))) (! (= var_48 var_98))) (! (= var_49 var_57))) (! (= var_49 var_58))) (! (= var_49 var_59))) (! (= var_49 var_67))) (! (= var_49 var_68))) (! (= var_49 var_69))) (! (= var_49 var_79))) (! (= var_49 var_89))) (! (= var_49 var_99))) (! (= var_51 var_52))) (! (= var_51 var_53))) (! (= var_51 var_54))) (! (= var_51 var_55))) (! (= var_51 var_56))) (! (= var_51 var_57))) (! (= var_51 var_58))) (! (= var_51 var_59))) (! (= var_51 var_61))) (! (= var_51 var_62))) (! (= var_51 var_63))) (! (= var_51 var_71))) (! (= var_51 var_81))) (! (= var_51 var_91))) (! (= var_52 var_53))) (! (= var_52 var_54))) (! (= var_52 var_55))) (! (= var_52 var_56))) (! (= var_52 var_57))) (! (= var_52 var_58))) (! (= var_52 var_59))) (! (= var_52 var_61))) (! (= var_52 var_62))) (! (= var_52 var_63))) (! (= var_52 var_72))) (! (= var_52 var_82))) (! (= var_52 var_92))) (! (= var_53 var_54))) (! (= var_53 var_55))) (! (= var_53 var_56))) (! (= var_53 var_57))) (! (= var_53 var_58))) (! (= var_53 var_59))) (! (= var_53 var_61))) (! (= var_53 var_62))) (! (= var_53 var_63))) (! (= var_53 var_73))) (! (= var_53 var_83))) (! (= var_53 var_93))) (! (= var_54 var_55))) (! (= var_54 var_56))) (! (= var_54 var_57))) (! (= var_54 var_58))) (! (= var_54 var_59))) (! (= var_54 var_64))) (! (= var_54 var_65))) (! (= var_54 var_66))) (! (= var_54 var_74))) (! (= var_54 var_84))) (! (= var_54 var_94))) (! (= var_55 var_56))) (! (= var_55 var_57))) (! (= var_55 var_58))) (! (= var_55 var_59))) (! (= var_55 var_64))) (! (= var_55 var_65))) (! (= var_55 var_66))) (! (= var_55 var_75))) (! (= var_55 var_85))) (! (= var_55 var_95))) (! (= var_56 var_57))) (! (= var_56 var_58))) (! (= var_56 var_59))) (! (= var_56 var_64))) (! (= var_56 var_65))) (! (= var_56 var_66))) (! (= var_56 var_76))) (! (= var_56 var_86))) (! (= var_56 var_96))) (! (= var_57 var_58))) (! (= var_57 var_59))) (! (= var_57 var_67))) (! (= var_57 var_68))) (! (= var_57 var_69))) (! (= var_57 var_77))) (! (= var_57 var_87))) (! (= var_57 var_97))) (! (= var_58 var_59))) (! (= var_58 var_67))) (! (= var_58 var_68))) (! (= var_58 var_69))) (! (= var_58 var_78))) (! (= var_58 var_88))) (! (= var_58 var_98))) (! (= var_59 var_67))) (! (= var_59 var_68))) (! (= var_59 var_69))) (! (= var_59 var_79))) (! (= var_59 var_89))) (! (= var_59 var_99))) (! (= var_61 var_62))) (! (= var_61 var_63))) (! (= var_61 var_64))) (! (= var_61 var_65))) (! (= var_61 var_66))) (! (= var_61 var_67))) (! (= var_61 var_68))) (! (= var_61 var_69))) (! (= var_61 var_71))) (! (= var_61 var_81))) (! (= var_61 var_91))) (! (= var_62 var_63))) (! (= var_62 var_64))) (! (= var_62 var_65))) (! (= var_62 var_66))) (! (= var_62 var_67))) (! (= var_62 var_68))) (! (= var_62 var_69))) (! (= var_62 var_72))) (! (= var_62 var_82))) (! (= var_62 var_92))) (! (= var_63 var_64))) (! (= var_63 var_65))) (! (= var_63 var_66))) (! (= var_63 var_67))) (! (= var_63 var_68))) (! (= var_63 var_69))) (! (= var_63 var_73))) (! (= var_63 var_83))) (! (= var_63 var_93))) (! (= var_64 var_65))) (! (= var_64 var_66))) (! (= var_64 var_67))) (! (= var_64 var_68))) (! (= var_64 var_69))) (! (= var_64 var_74))) (! (= var_64 var_84))) (! (= var_64 var_94))) (! (= var_65 var_66))) (! (= var_65 var_67))) (! (= var_65 var_68))) (! (= var_65 var_69))) (! (= var_65 var_75))) (! (= var_65 var_85))) (! (= var_65 var_95))) (! (= var_66 var_67))) (! (= var_66 var_68))) (! (= var_66 var_69))) (! (= var_66 var_76))) (! (= var_66 var_86))) (! (= var_66 var_96))) (! (= var_67 var_68))) (! (= var_67 var_69))) (! (= var_67 var_77))) (! (= var_67 var_87))) (! (= var_67 var_97))) (! (= var_68 var_69))) (! (= var_68 var_78))) (! (= var_68 var_88))) (! (= var_68 var_98))) (! (= var_69 var_79))) (! (= var_69 var_89))) (! (= var_69 var_99))) (! (= var_71 var_72))) (! (= var_71 var_73))) (! (= var_71 var_74))) (! (= var_71 var_75))) (! (= var_71 var_76))) (! (= var_71 var_77))) (! (= var_71 var_78))) (! (= var_71 var_79))) (! (= var_71 var_81))) (! (= var_71 var_82))) (! (= var_71 var_83))) (! (= var_71 var_91))) (! (= var_71 var_92))) (! (= var_71 var_93))) (! (= var_72 var_73))) (! (= var_72 var_74))) (! (= var_72 var_75))) (! (= var_72 var_76))) (! (= var_72 var_77))) (! (= var_72 var_78))) (! (= var_72 var_79))) (! (= var_72 var_81))) (! (= var_72 var_82))) (! (= var_72 var_83))) (! (= var_72 var_91))) (! (= var_72 var_92))) (! (= var_72 var_93))) (! (= var_73 var_74))) (! (= var_73 var_75))) (! (= var_73 var_76))) (! (= var_73 var_77))) (! (= var_73 var_78))) (! (= var_73 var_79))) (! (= var_73 var_81))) (! (= var_73 var_82))) (! (= var_73 var_83))) (! (= var_73 var_91))) (! (= var_73 var_92))) (! (= var_73 var_93))) (! (= var_74 var_75))) (! (= var_74 var_76))) (! (= var_74 var_77))) (! (= var_74 var_78))) (! (= var_74 var_79))) (! (= var_74 var_84))) (! (= var_74 var_85))) (! (= var_74 var_86))) (! (= var_74 var_94))) (! (= var_74 var_95))) (! (= var_74 var_96))) (! (= var_75 var_76))) (! (= var_75 var_77))) (! (= var_75 var_78))) (! (= var_75 var_79))) (! (= var_75 var_84))) (! (= var_75 var_85))) (! (= var_75 var_86))) (! (= var_75 var_94))) (! (= var_75 var_95))) (! (= var_75 var_96))) (! (= var_76 var_77))) (! (= var_76 var_78))) (! (= var_76 var_79))) (! (= var_76 var_84))) (! (= var_76 var_85))) (! (= var_76 var_86))) (! (= var_76 var_94))) (! (= var_76 var_95))) (! (= var_76 var_96))) (! (= var_77 var_78))) (! (= var_77 var_79))) (! (= var_77 var_87))) (! (= var_77 var_88))) (! (= var_77 var_89))) (! (= var_77 var_97))) (! (= var_77 var_98))) (! (= var_77 var_99))) (! (= var_78 var_79))) (! (= var_78 var_87))) (! (= var_78 var_88))) (! (= var_78 var_89))) (! (= var_78 var_97))) (! (= var_78 var_98))) (! (= var_78 var_99))) (! (= var_79 var_87))) (! (= var_79 var_88))) (! (= var_79 var_89))) (! (= var_79 var_97))) (! (= var_79 var_98))) (! (= var_79 var_99))) (! (= var_81 var_82))) (! (= var_81 var_83))) (! (= var_81 var_84))) (! (= var_81 var_85))) (! (= var_81 var_86))) (! (= var_81 var_87))) (! (= var_81 var_88))) (! (= var_81 var_89))) (! (= var_81 var_91))) (! (= var_81 var_92))) (! (= var_81 var_93))) (! (= var_82 var_83))) (! (= var_82 var_84))) (! (= var_82 var_85))) (! (= var_82 var_86))) (! (= var_82 var_87))) (! (= var_82 var_88))) (! (= var_82 var_89))) (! (= var_82 var_91))) (! (= var_82 var_92))) (! (= var_82 var_93))) (! (= var_83 var_84))) (! (= var_83 var_85))) (! (= var_83 var_86))) (! (= var_83 var_87))) (! (= var_83 var_88))) (! (= var_83 var_89))) (! (= var_83 var_91))) (! (= var_83 var_92))) (! (= var_83 var_93))) (! (= var_84 var_85))) (! (= var_84 var_86))) (! (= var_84 var_87))) (! (= var_84 var_88))) (! (= var_84 var_89))) (! (= var_84 var_94))) (! (= var_84 var_95))) (! (= var_84 var_96))) (! (= var_85 var_86))) (! (= var_85 var_87))) (! (= var_85 var_88))) (! (= var_85 var_89))) (! (= var_85 var_94))) (! (= var_85 var_95))) (! (= var_85 var_96))) (! (= var_86 var_87))) (! (= var_86 var_88))) (! (= var_86 var_89))) (! (= var_86 var_94))) (! (= var_86 var_95))) (! (= var_86 var_96))) (! (= var_87 var_88))) (! (= var_87 var_89))) (! (= var_87 var_97))) (! (= var_87 var_98))) (! (= var_87 var_99))) (! (= var_88 var_89))) (! (= var_88 var_97))) (! (= var_88 var_98))) (! (= var_88 var_99))) (! (= var_89 var_97))) (! (= var_89 var_98))) (! (= var_89 var_99))) (! (= var_91 var_92))) (! (= var_91 var_93))) (! (= var_91 var_94))) (! (= var_91 var_95))) (! (= var_91 var_96))) (! (= var_91 var_97))) (! (= var_91 var_98))) (! (= var_91 var_99))) (! (= var_92 var_93))) (! (= var_92 var_94))) (! (= var_92 var_95))) (! (= var_92 var_96))) (! (= var_92 var_97))) (! (= var_92 var_98))) (! (= var_92 var_99))) (! (= var_93 var_94))) (! (= var_93 var_95))) (! (= var_93 var_96))) (! (= var_93 var_97))) (! (= var_93 var_98))) (! (= var_93 var_99))) (! (= var_94 var_95))) (! (= var_94 var_96))) (! (= var_94 var_97))) (! (= var_94 var_98))) (! (= var_94 var_99))) (! (= var_95 var_96))) (! (= var_95 var_97))) (! (= var_95 var_98))) (! (= var_95 var_99))) (! (= var_96 var_97))) (! (= var_96 var_98))) (! (= var_96 var_99))) (! (= var_97 var_98))) (! (= var_97 var_99))) (! (= var_98 var_99)))"

# expr = "(& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (! (= var_11 var_12)) (! (= var_11 var_13))) (! (= var_11 var_14))) (! (= var_11 var_15))) (! (= var_11 var_16))) (! (= var_11 var_17))) (! (= var_11 var_18))) (! (= var_11 var_19))) (! (= var_11 var_21))) (! (= var_11 var_22))) (! (= var_11 var_23))) (! (= var_11 var_31))) (! (= var_11 var_32))) (! (= var_11 var_33))) (! (= var_11 var_41))) (! (= var_11 var_51))) (! (= var_11 var_61))) (! (= var_11 var_71))) (! (= var_11 var_81))) (! (= var_11 var_91))) (! (= var_12 var_13))) (! (= var_12 var_14))) (! (= var_12 var_15))) (! (= var_12 var_16))) (! (= var_12 var_17))) (! (= var_12 var_18))) (! (= var_12 var_19))) (! (= var_12 var_21))) (! (= var_12 var_22))) (! (= var_12 var_23))) (! (= var_12 var_31))) (! (= var_12 var_32))) (! (= var_12 var_33))) (! (= var_12 var_42))) (! (= var_12 var_52))) (! (= var_12 var_62))) (! (= var_12 var_72))) (! (= var_12 var_82))) (! (= var_12 var_92))) (! (= var_13 var_14))) (! (= var_13 var_15))) (! (= var_13 var_16))) (! (= var_13 var_17))) (! (= var_13 var_18))) (! (= var_13 var_19))) (! (= var_13 var_21))) (! (= var_13 var_22))) (! (= var_13 var_23))) (! (= var_13 var_31))) (! (= var_13 var_32))) (! (= var_13 var_33))) (! (= var_13 var_43))) (! (= var_13 var_53))) (! (= var_13 var_63))) (! (= var_13 var_73))) (! (= var_13 var_83))) (! (= var_13 var_93))) (! (= var_14 var_15))) (! (= var_14 var_16))) (! (= var_14 var_17))) (! (= var_14 var_18))) (! (= var_14 var_19))) (! (= var_14 var_24))) (! (= var_14 var_25))) (! (= var_14 var_26))) (! (= var_14 var_34))) (! (= var_14 var_35))) (! (= var_14 var_36))) (! (= var_14 var_44))) (! (= var_14 var_54))) (! (= var_14 var_64))) (! (= var_14 var_74))) (! (= var_14 var_84))) (! (= var_14 var_94))) (! (= var_15 var_16))) (! (= var_15 var_17))) (! (= var_15 var_18))) (! (= var_15 var_19))) (! (= var_15 var_24))) (! (= var_15 var_25))) (! (= var_15 var_26))) (! (= var_15 var_34))) (! (= var_15 var_35))) (! (= var_15 var_36))) (! (= var_15 var_45))) (! (= var_15 var_55))) (! (= var_15 var_65))) (! (= var_15 var_75))) (! (= var_15 var_85))) (! (= var_15 var_95))) (! (= var_16 var_17))) (! (= var_16 var_18))) (! (= var_16 var_19))) (! (= var_16 var_24))) (! (= var_16 var_25))) (! (= var_16 var_26))) (! (= var_16 var_34))) (! (= var_16 var_35))) (! (= var_16 var_36))) (! (= var_16 var_46))) (! (= var_16 var_56))) (! (= var_16 var_66))) (! (= var_16 var_76))) (! (= var_16 var_86))) (! (= var_16 var_96))) (! (= var_17 var_18))) (! (= var_17 var_19))) (! (= var_17 var_27))) (! (= var_17 var_28))) (! (= var_17 var_29))) (! (= var_17 var_37))) (! (= var_17 var_38))) (! (= var_17 var_39))) (! (= var_17 var_47))) (! (= var_17 var_57))) (! (= var_17 var_67))) (! (= var_17 var_77))) (! (= var_17 var_87))) (! (= var_17 var_97))) (! (= var_18 var_19))) (! (= var_18 var_27))) (! (= var_18 var_28))) (! (= var_18 var_29))) (! (= var_18 var_37))) (! (= var_18 var_38))) (! (= var_18 var_39))) (! (= var_18 var_48))) (! (= var_18 var_58))) (! (= var_18 var_68))) (! (= var_18 var_78))) (! (= var_18 var_88))) (! (= var_18 var_98))) (! (= var_19 var_27))) (! (= var_19 var_28))) (! (= var_19 var_29))) (! (= var_19 var_37))) (! (= var_19 var_38))) (! (= var_19 var_39))) (! (= var_19 var_49))) (! (= var_19 var_59))) (! (= var_19 var_69))) (! (= var_19 var_79))) (! (= var_19 var_89))) (! (= var_19 var_99))) (! (= var_21 var_22))) (! (= var_21 var_23))) (! (= var_21 var_24))) (! (= var_21 var_25))) (! (= var_21 var_26))) (! (= var_21 var_27))) (! (= var_21 var_28))) (! (= var_21 var_29))) (! (= var_21 var_31))) (! (= var_21 var_32))) (! (= var_21 var_33))) (! (= var_21 var_41))) (! (= var_21 var_51))) (! (= var_21 var_61))) (! (= var_21 var_71))) (! (= var_21 var_81))) (! (= var_21 var_91))) (! (= var_22 var_23))) (! (= var_22 var_24))) (! (= var_22 var_25))) (! (= var_22 var_26))) (! (= var_22 var_27))) (! (= var_22 var_28))) (! (= var_22 var_29))) (! (= var_22 var_31))) (! (= var_22 var_32))) (! (= var_22 var_33))) (! (= var_22 var_42))) (! (= var_22 var_52))) (! (= var_22 var_62))) (! (= var_22 var_72))) (! (= var_22 var_82))) (! (= var_22 var_92))) (! (= var_23 var_24))) (! (= var_23 var_25))) (! (= var_23 var_26))) (! (= var_23 var_27))) (! (= var_23 var_28))) (! (= var_23 var_29))) (! (= var_23 var_31))) (! (= var_23 var_32))) (! (= var_23 var_33))) (! (= var_23 var_43))) (! (= var_23 var_53))) (! (= var_23 var_63))) (! (= var_23 var_73))) (! (= var_23 var_83))) (! (= var_23 var_93))) (! (= var_24 var_25))) (! (= var_24 var_26))) (! (= var_24 var_27))) (! (= var_24 var_28))) (! (= var_24 var_29))) (! (= var_24 var_34))) (! (= var_24 var_35))) (! (= var_24 var_36))) (! (= var_24 var_44))) (! (= var_24 var_54))) (! (= var_24 var_64))) (! (= var_24 var_74))) (! (= var_24 var_84))) (! (= var_24 var_94))) (! (= var_25 var_26))) (! (= var_25 var_27))) (! (= var_25 var_28))) (! (= var_25 var_29))) (! (= var_25 var_34))) (! (= var_25 var_35))) (! (= var_25 var_36))) (! (= var_25 var_45))) (! (= var_25 var_55))) (! (= var_25 var_65))) (! (= var_25 var_75))) (! (= var_25 var_85))) (! (= var_25 var_95))) (! (= var_26 var_27))) (! (= var_26 var_28))) (! (= var_26 var_29))) (! (= var_26 var_34))) (! (= var_26 var_35))) (! (= var_26 var_36))) (! (= var_26 var_46))) (! (= var_26 var_56))) (! (= var_26 var_66))) (! (= var_26 var_76))) (! (= var_26 var_86))) (! (= var_26 var_96))) (! (= var_27 var_28))) (! (= var_27 var_29))) (! (= var_27 var_37))) (! (= var_27 var_38))) (! (= var_27 var_39))) (! (= var_27 var_47))) (! (= var_27 var_57))) (! (= var_27 var_67))) (! (= var_27 var_77))) (! (= var_27 var_87))) (! (= var_27 var_97))) (! (= var_28 var_29))) (! (= var_28 var_37))) (! (= var_28 var_38))) (! (= var_28 var_39))) (! (= var_28 var_48))) (! (= var_28 var_58))) (! (= var_28 var_68))) (! (= var_28 var_78))) (! (= var_28 var_88))) (! (= var_28 var_98))) (! (= var_29 var_37))) (! (= var_29 var_38))) (! (= var_29 var_39))) (! (= var_29 var_49))) (! (= var_29 var_59))) (! (= var_29 var_69))) (! (= var_29 var_79))) (! (= var_29 var_89))) (! (= var_29 var_99))) (! (= var_31 var_32))) (! (= var_31 var_33))) (! (= var_31 var_34))) (! (= var_31 var_35))) (! (= var_31 var_36))) (! (= var_31 var_37))) (! (= var_31 var_38))) (! (= var_31 var_39))) (! (= var_31 var_41))) (! (= var_31 var_51))) (! (= var_31 var_61))) (! (= var_31 var_71))) (! (= var_31 var_81))) (! (= var_31 var_91))) (! (= var_32 var_33))) (! (= var_32 var_34))) (! (= var_32 var_35))) (! (= var_32 var_36))) (! (= var_32 var_37))) (! (= var_32 var_38))) (! (= var_32 var_39))) (! (= var_32 var_42))) (! (= var_32 var_52))) (! (= var_32 var_62))) (! (= var_32 var_72))) (! (= var_32 var_82))) (! (= var_32 var_92))) (! (= var_33 var_34))) (! (= var_33 var_35))) (! (= var_33 var_36))) (! (= var_33 var_37))) (! (= var_33 var_38))) (! (= var_33 var_39))) (! (= var_33 var_43))) (! (= var_33 var_53))) (! (= var_33 var_63))) (! (= var_33 var_73))) (! (= var_33 var_83))) (! (= var_33 var_93))) (! (= var_34 var_35))) (! (= var_34 var_36))) (! (= var_34 var_37))) (! (= var_34 var_38))) (! (= var_34 var_39))) (! (= var_34 var_44))) (! (= var_34 var_54))) (! (= var_34 var_64))) (! (= var_34 var_74))) (! (= var_34 var_84))) (! (= var_34 var_94))) (! (= var_35 var_36))) (! (= var_35 var_37))) (! (= var_35 var_38))) (! (= var_35 var_39))) (! (= var_35 var_45))) (! (= var_35 var_55))) (! (= var_35 var_65))) (! (= var_35 var_75))) (! (= var_35 var_85))) (! (= var_35 var_95))) (! (= var_36 var_37))) (! (= var_36 var_38))) (! (= var_36 var_39))) (! (= var_36 var_46))) (! (= var_36 var_56))) (! (= var_36 var_66))) (! (= var_36 var_76))) (! (= var_36 var_86))) (! (= var_36 var_96))) (! (= var_37 var_38))) (! (= var_37 var_39))) (! (= var_37 var_47))) (! (= var_37 var_57))) (! (= var_37 var_67))) (! (= var_37 var_77))) (! (= var_37 var_87))) (! (= var_37 var_97))) (! (= var_38 var_39))) (! (= var_38 var_48))) (! (= var_38 var_58))) (! (= var_38 var_68))) (! (= var_38 var_78))) (! (= var_38 var_88))) (! (= var_38 var_98))) (! (= var_39 var_49))) (! (= var_39 var_59))) (! (= var_39 var_69))) (! (= var_39 var_79))) (! (= var_39 var_89))) (! (= var_39 var_99))) (! (= var_41 var_42))) (! (= var_41 var_43))) (! (= var_41 var_44))) (! (= var_41 var_45))) (! (= var_41 var_46))) (! (= var_41 var_47))) (! (= var_41 var_48))) (! (= var_41 var_49))) (! (= var_41 var_51))) (! (= var_41 var_52))) (! (= var_41 var_53))) (! (= var_41 var_61))) (! (= var_41 var_62))) (! (= var_41 var_63))) (! (= var_41 var_71))) (! (= var_41 var_81))) (! (= var_41 var_91))) (! (= var_42 var_43))) (! (= var_42 var_44))) (! (= var_42 var_45))) (! (= var_42 var_46))) (! (= var_42 var_47))) (! (= var_42 var_48))) (! (= var_42 var_49))) (! (= var_42 var_51))) (! (= var_42 var_52))) (! (= var_42 var_53))) (! (= var_42 var_61))) (! (= var_42 var_62))) (! (= var_42 var_63))) (! (= var_42 var_72))) (! (= var_42 var_82))) (! (= var_42 var_92))) (! (= var_43 var_44))) (! (= var_43 var_45))) (! (= var_43 var_46))) (! (= var_43 var_47))) (! (= var_43 var_48))) (! (= var_43 var_49))) (! (= var_43 var_51))) (! (= var_43 var_52))) (! (= var_43 var_53))) (! (= var_43 var_61))) (! (= var_43 var_62))) (! (= var_43 var_63))) (! (= var_43 var_73))) (! (= var_43 var_83))) (! (= var_43 var_93))) (! (= var_44 var_45))) (! (= var_44 var_46))) (! (= var_44 var_47))) (! (= var_44 var_48))) (! (= var_44 var_49))) (! (= var_44 var_54))) (! (= var_44 var_55))) (! (= var_44 var_56))) (! (= var_44 var_64))) (! (= var_44 var_65))) (! (= var_44 var_66))) (! (= var_44 var_74))) (! (= var_44 var_84))) (! (= var_44 var_94))) (! (= var_45 var_46))) (! (= var_45 var_47))) (! (= var_45 var_48))) (! (= var_45 var_49))) (! (= var_45 var_54))) (! (= var_45 var_55))) (! (= var_45 var_56))) (! (= var_45 var_64))) (! (= var_45 var_65))) (! (= var_45 var_66))) (! (= var_45 var_75))) (! (= var_45 var_85))) (! (= var_45 var_95))) (! (= var_46 var_47))) (! (= var_46 var_48))) (! (= var_46 var_49))) (! (= var_46 var_54))) (! (= var_46 var_55))) (! (= var_46 var_56))) (! (= var_46 var_64))) (! (= var_46 var_65))) (! (= var_46 var_66))) (! (= var_46 var_76))) (! (= var_46 var_86))) (! (= var_46 var_96))) (! (= var_47 var_48))) (! (= var_47 var_49))) (! (= var_47 var_57))) (! (= var_47 var_58))) (! (= var_47 var_59))) (! (= var_47 var_67))) (! (= var_47 var_68))) (! (= var_47 var_69))) (! (= var_47 var_77))) (! (= var_47 var_87))) (! (= var_47 var_97))) (! (= var_48 var_49))) (! (= var_48 var_57))) (! (= var_48 var_58))) (! (= var_48 var_59))) (! (= var_48 var_67))) (! (= var_48 var_68))) (! (= var_48 var_69))) (! (= var_48 var_78))) (! (= var_48 var_88))) (! (= var_48 var_98))) (! (= var_49 var_57))) (! (= var_49 var_58))) (! (= var_49 var_59))) (! (= var_49 var_67))) (! (= var_49 var_68))) (! (= var_49 var_69))) (! (= var_49 var_79))) (! (= var_49 var_89))) (! (= var_49 var_99))) (! (= var_51 var_52))) (! (= var_51 var_53))) (! (= var_51 var_54))) (! (= var_51 var_55))) (! (= var_51 var_56))) (! (= var_51 var_57))) (! (= var_51 var_58))) (! (= var_51 var_59))) (! (= var_51 var_61))) (! (= var_51 var_62))) (! (= var_51 var_63))) (! (= var_51 var_71))) (! (= var_51 var_81))) (! (= var_51 var_91))) (! (= var_52 var_53))) (! (= var_52 var_54))) (! (= var_52 var_55))) (! (= var_52 var_56))) (! (= var_52 var_57))) (! (= var_52 var_58))) (! (= var_52 var_59))) (! (= var_52 var_61))) (! (= var_52 var_62))) (! (= var_52 var_63))) (! (= var_52 var_72))) (! (= var_52 var_82))) (! (= var_52 var_92))) (! (= var_53 var_54))) (! (= var_53 var_55))) (! (= var_53 var_56))) (! (= var_53 var_57))) (! (= var_53 var_58))) (! (= var_53 var_59))) (! (= var_53 var_61))) (! (= var_53 var_62))) (! (= var_53 var_63))) (! (= var_53 var_73))) (! (= var_53 var_83))) (! (= var_53 var_93))) (! (= var_54 var_55))) (! (= var_54 var_56))) (! (= var_54 var_57))) (! (= var_54 var_58))) (! (= var_54 var_59))) (! (= var_54 var_64))) (! (= var_54 var_65))) (! (= var_54 var_66))) (! (= var_54 var_74))) (! (= var_54 var_84))) (! (= var_54 var_94))) (! (= var_55 var_56))) (! (= var_55 var_57))) (! (= var_55 var_58))) (! (= var_55 var_59))) (! (= var_55 var_64))) (! (= var_55 var_65))) (! (= var_55 var_66))) (! (= var_55 var_75))) (! (= var_55 var_85))) (! (= var_55 var_95))) (! (= var_56 var_57))) (! (= var_56 var_58))) (! (= var_56 var_59))) (! (= var_56 var_64))) (! (= var_56 var_65))) (! (= var_56 var_66))) (! (= var_56 var_76))) (! (= var_56 var_86))) (! (= var_56 var_96))) (! (= var_57 var_58))) (! (= var_57 var_59))) (! (= var_57 var_67))) (! (= var_57 var_68))) (! (= var_57 var_69))) (! (= var_57 var_77))) (! (= var_57 var_87))) (! (= var_57 var_97))) (! (= var_58 var_59))) (! (= var_58 var_67))) (! (= var_58 var_68))) (! (= var_58 var_69))) (! (= var_58 var_78))) (! (= var_58 var_88))) (! (= var_58 var_98))) (! (= var_59 var_67))) (! (= var_59 var_68))) (! (= var_59 var_69))) (! (= var_59 var_79))) (! (= var_59 var_89))) (! (= var_59 var_99))) (! (= var_61 var_62))) (! (= var_61 var_63))) (! (= var_61 var_64))) (! (= var_61 var_65))) (! (= var_61 var_66))) (! (= var_61 var_67))) (! (= var_61 var_68))) (! (= var_61 var_69))) (! (= var_61 var_71))) (! (= var_61 var_81))) (! (= var_61 var_91))) (! (= var_62 var_63))) (! (= var_62 var_64))) (! (= var_62 var_65))) (! (= var_62 var_66))) (! (= var_62 var_67))) (! (= var_62 var_68))) (! (= var_62 var_69))) (! (= var_62 var_72))) (! (= var_62 var_82))) (! (= var_62 var_92))) (! (= var_63 var_64))) (! (= var_63 var_65))) (! (= var_63 var_66))) (! (= var_63 var_67))) (! (= var_63 var_68))) (! (= var_63 var_69))) (! (= var_63 var_73))) (! (= var_63 var_83))) (! (= var_63 var_93))) (! (= var_64 var_65))) (! (= var_64 var_66))) (! (= var_64 var_67))) (! (= var_64 var_68))) (! (= var_64 var_69))) (! (= var_64 var_74))) (! (= var_64 var_84))) (! (= var_64 var_94))) (! (= var_65 var_66))) (! (= var_65 var_67))) (! (= var_65 var_68))) (! (= var_65 var_69))) (! (= var_65 var_75))) (! (= var_65 var_85))) (! (= var_65 var_95))) (! (= var_66 var_67))) (! (= var_66 var_68))) (! (= var_66 var_69))) (! (= var_66 var_76))) (! (= var_66 var_86))) (! (= var_66 var_96))) (! (= var_67 var_68))) (! (= var_67 var_69))) (! (= var_67 var_77))) (! (= var_67 var_87))) (! (= var_67 var_97))) (! (= var_68 var_69))) (! (= var_68 var_78))) (! (= var_68 var_88))) (! (= var_68 var_98))) (! (= var_69 var_79))) (! (= var_69 var_89))) (! (= var_69 var_99))) (! (= var_71 var_72))) (! (= var_71 var_73))) (! (= var_71 var_74))) (! (= var_71 var_75))) (! (= var_71 var_76))) (! (= var_71 var_77))) (! (= var_71 var_78))) (! (= var_71 var_79))) (! (= var_71 var_81))) (! (= var_71 var_82))) (! (= var_71 var_83))) (! (= var_71 var_91))) (! (= var_71 var_92))) (! (= var_71 var_93))) (! (= var_72 var_73))) (! (= var_72 var_74))) (! (= var_72 var_75))) (! (= var_72 var_76))) (! (= var_72 var_77))) (! (= var_72 var_78))) (! (= var_72 var_79))) (! (= var_72 var_81))) (! (= var_72 var_82))) (! (= var_72 var_83))) (! (= var_72 var_91))) (! (= var_72 var_92))) (! (= var_72 var_93))) (! (= var_73 var_74))) (! (= var_73 var_75))) (! (= var_73 var_76))) (! (= var_73 var_77))) (! (= var_73 var_78))) (! (= var_73 var_79))) (! (= var_73 var_81))) (! (= var_73 var_82))) (! (= var_73 var_83))) (! (= var_73 var_91))) (! (= var_73 var_92))) (! (= var_73 var_93))) (! (= var_74 var_75))) (! (= var_74 var_76))) (! (= var_74 var_77))) (! (= var_74 var_78))) (! (= var_74 var_79))) (! (= var_74 var_84))) (! (= var_74 var_85))) (! (= var_74 var_86))) (! (= var_74 var_94))) (! (= var_74 var_95))) (! (= var_74 var_96))) (! (= var_75 var_76))) (! (= var_75 var_77))) (! (= var_75 var_78))) (! (= var_75 var_79))) (! (= var_75 var_84))) (! (= var_75 var_85))) (! (= var_75 var_86))) (! (= var_75 var_94))) (! (= var_75 var_95))) (! (= var_75 var_96))) (! (= var_76 var_77))) (! (= var_76 var_78))) (! (= var_76 var_79))) (! (= var_76 var_84))) (! (= var_76 var_85))) (! (= var_76 var_86))) (! (= var_76 var_94))) (! (= var_76 var_95))) (! (= var_76 var_96))) (! (= var_77 var_78))) (! (= var_77 var_79))) (! (= var_77 var_87))) (! (= var_77 var_88))) (! (= var_77 var_89))) (! (= var_77 var_97))) (! (= var_77 var_98))) (! (= var_77 var_99))) (! (= var_78 var_79))) (! (= var_78 var_87))) (! (= var_78 var_88))) (! (= var_78 var_89))) (! (= var_78 var_97))) (! (= var_78 var_98))) (! (= var_78 var_99))) (! (= var_79 var_87))) (! (= var_79 var_88))) (! (= var_79 var_89))) (! (= var_79 var_97))) (! (= var_79 var_98))) (! (= var_79 var_99))) (! (= var_81 var_82))) (! (= var_81 var_83))) (! (= var_81 var_84))) (! (= var_81 var_85))) (! (= var_81 var_86))) (! (= var_81 var_87))) (! (= var_81 var_88))) (! (= var_81 var_89))) (! (= var_81 var_91))) (! (= var_81 var_92))) (! (= var_81 var_93))) (! (= var_82 var_83))) (! (= var_82 var_84))) (! (= var_82 var_85))) (! (= var_82 var_86))) (! (= var_82 var_87))) (! (= var_82 var_88))) (! (= var_82 var_89))) (! (= var_82 var_91))) (! (= var_82 var_92))) (! (= var_82 var_93))) (! (= var_83 var_84))) (! (= var_83 var_85))) (! (= var_83 var_86))) (! (= var_83 var_87))) (! (= var_83 var_88))) (! (= var_83 var_89))) (! (= var_83 var_91))) (! (= var_83 var_92))) (! (= var_83 var_93))) (! (= var_84 var_85))) (! (= var_84 var_86))) (! (= var_84 var_87))) (! (= var_84 var_88))) (! (= var_84 var_89))) (! (= var_84 var_94))) (! (= var_84 var_95))) (! (= var_84 var_96))) (! (= var_85 var_86))) (! (= var_85 var_87))) (! (= var_85 var_88))) (! (= var_85 var_89))) (! (= var_85 var_94))) (! (= var_85 var_95))) (! (= var_85 var_96))) (! (= var_86 var_87))) (! (= var_86 var_88))) (! (= var_86 var_89))) (! (= var_86 var_94))) (! (= var_86 var_95))) (! (= var_86 var_96))) (! (= var_87 var_88))) (! (= var_87 var_89))) (! (= var_87 var_97))) (! (= var_87 var_98))) (! (= var_87 var_99))) (! (= var_88 var_89))) (! (= var_88 var_97))) (! (= var_88 var_98))) (! (= var_88 var_99))) (! (= var_89 var_97))) (! (= var_89 var_98))) (! (= var_89 var_99))) (! (= var_91 var_92))) (! (= var_91 var_93))) (! (= var_91 var_94))) (! (= var_91 var_95))) (! (= var_91 var_96))) (! (= var_91 var_97))) (! (= var_91 var_98))) (! (= var_91 var_99))) (! (= var_92 var_93))) (! (= var_92 var_94))) (! (= var_92 var_95))) (! (= var_92 var_96))) (! (= var_92 var_97))) (! (= var_92 var_98))) (! (= var_92 var_99))) (! (= var_93 var_94))) (! (= var_93 var_95))) (! (= var_93 var_96))) (! (= var_93 var_97))) (! (= var_93 var_98))) (! (= var_93 var_99))) (! (= var_94 var_95))) (! (= var_94 var_96))) (! (= var_94 var_97))) (! (= var_94 var_98))) (! (= var_94 var_99))) (! (= var_95 var_96))) (! (= var_95 var_97))) (! (= var_95 var_98))) (! (= var_95 var_99))) (! (= var_96 var_97))) (! (= var_96 var_98))) (! (= var_96 var_99))) (! (= var_97 var_98))) (! (= var_97 var_99))) (! (= var_98 var_99))) (= var_17 6)) (= var_18 8)) (= var_25 7)) (= var_26 3)) (= var_29 9)) (= var_31 3)) (= var_33 9)) (= var_38 4)) (= var_39 5)) (= var_41 4)) (= var_42 9)) (= var_51 8)) (= var_53 3)) (= var_55 5)) (= var_57 9)) (= var_59 2)) (= var_68 3)) (= var_69 6)) (= var_71 9)) (= var_72 6)) (= var_77 3)) (= var_79 8)) (= var_81 7)) (= var_84 6)) (= var_85 8)) (= var_92 2)) (= var_93 8))"

expr = "(& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (& (! (= var_11 var_12)) (! (= var_11 var_13))) (! (= var_11 var_14))) (! (= var_11 var_15))) (! (= var_11 var_16))) (! (= var_11 var_17))) (! (= var_11 var_18))) (! (= var_11 var_19))) (! (= var_11 var_21))) (! (= var_11 var_22))) (! (= var_11 var_23))) (! (= var_11 var_31))) (! (= var_11 var_32))) (! (= var_11 var_33))) (! (= var_11 var_41))) (! (= var_11 var_51))) (! (= var_11 var_61))) (! (= var_11 var_71))) (! (= var_11 var_81))) (! (= var_11 var_91))) (! (= var_12 var_13))) (! (= var_12 var_14))) (! (= var_12 var_15))) (! (= var_12 var_16))) (! (= var_12 var_17))) (! (= var_12 var_18))) (! (= var_12 var_19))) (! (= var_12 var_21))) (! (= var_12 var_22))) (! (= var_12 var_23))) (! (= var_12 var_31))) (! (= var_12 var_32))) (! (= var_12 var_33))) (! (= var_12 var_42))) (! (= var_12 var_52))) (! (= var_12 var_62))) (! (= var_12 var_72))) (! (= var_12 var_82))) (! (= var_12 var_92))) (! (= var_13 var_14))) (! (= var_13 var_15))) (! (= var_13 var_16))) (! (= var_13 var_17))) (! (= var_13 var_18))) (! (= var_13 var_19))) (! (= var_13 var_21))) (! (= var_13 var_22))) (! (= var_13 var_23))) (! (= var_13 var_31))) (! (= var_13 var_32))) (! (= var_13 var_33))) (! (= var_13 var_43))) (! (= var_13 var_53))) (! (= var_13 var_63))) (! (= var_13 var_73))) (! (= var_13 var_83))) (! (= var_13 var_93))) (! (= var_14 var_15))) (! (= var_14 var_16))) (! (= var_14 var_17))) (! (= var_14 var_18))) (! (= var_14 var_19))) (! (= var_14 var_24))) (! (= var_14 var_25))) (! (= var_14 var_26))) (! (= var_14 var_34))) (! (= var_14 var_35))) (! (= var_14 var_36))) (! (= var_14 var_44))) (! (= var_14 var_54))) (! (= var_14 var_64))) (! (= var_14 var_74))) (! (= var_14 var_84))) (! (= var_14 var_94))) (! (= var_15 var_16))) (! (= var_15 var_17))) (! (= var_15 var_18))) (! (= var_15 var_19))) (! (= var_15 var_24))) (! (= var_15 var_25))) (! (= var_15 var_26))) (! (= var_15 var_34))) (! (= var_15 var_35))) (! (= var_15 var_36))) (! (= var_15 var_45))) (! (= var_15 var_55))) (! (= var_15 var_65))) (! (= var_15 var_75))) (! (= var_15 var_85))) (! (= var_15 var_95))) (! (= var_16 var_17))) (! (= var_16 var_18))) (! (= var_16 var_19))) (! (= var_16 var_24))) (! (= var_16 var_25))) (! (= var_16 var_26))) (! (= var_16 var_34))) (! (= var_16 var_35))) (! (= var_16 var_36))) (! (= var_16 var_46))) (! (= var_16 var_56))) (! (= var_16 var_66))) (! (= var_16 var_76))) (! (= var_16 var_86))) (! (= var_16 var_96))) (! (= var_17 var_18))) (! (= var_17 var_19))) (! (= var_17 var_27))) (! (= var_17 var_28))) (! (= var_17 var_29))) (! (= var_17 var_37))) (! (= var_17 var_38))) (! (= var_17 var_39))) (! (= var_17 var_47))) (! (= var_17 var_57))) (! (= var_17 var_67))) (! (= var_17 var_77))) (! (= var_17 var_87))) (! (= var_17 var_97))) (! (= var_18 var_19))) (! (= var_18 var_27))) (! (= var_18 var_28))) (! (= var_18 var_29))) (! (= var_18 var_37))) (! (= var_18 var_38))) (! (= var_18 var_39))) (! (= var_18 var_48))) (! (= var_18 var_58))) (! (= var_18 var_68))) (! (= var_18 var_78))) (! (= var_18 var_88))) (! (= var_18 var_98))) (! (= var_19 var_27))) (! (= var_19 var_28))) (! (= var_19 var_29))) (! (= var_19 var_37))) (! (= var_19 var_38))) (! (= var_19 var_39))) (! (= var_19 var_49))) (! (= var_19 var_59))) (! (= var_19 var_69))) (! (= var_19 var_79))) (! (= var_19 var_89))) (! (= var_19 var_99))) (! (= var_21 var_22))) (! (= var_21 var_23))) (! (= var_21 var_24))) (! (= var_21 var_25))) (! (= var_21 var_26))) (! (= var_21 var_27))) (! (= var_21 var_28))) (! (= var_21 var_29))) (! (= var_21 var_31))) (! (= var_21 var_32))) (! (= var_21 var_33))) (! (= var_21 var_41))) (! (= var_21 var_51))) (! (= var_21 var_61))) (! (= var_21 var_71))) (! (= var_21 var_81))) (! (= var_21 var_91))) (! (= var_22 var_23))) (! (= var_22 var_24))) (! (= var_22 var_25))) (! (= var_22 var_26))) (! (= var_22 var_27))) (! (= var_22 var_28))) (! (= var_22 var_29))) (! (= var_22 var_31))) (! (= var_22 var_32))) (! (= var_22 var_33))) (! (= var_22 var_42))) (! (= var_22 var_52))) (! (= var_22 var_62))) (! (= var_22 var_72))) (! (= var_22 var_82))) (! (= var_22 var_92))) (! (= var_23 var_24))) (! (= var_23 var_25))) (! (= var_23 var_26))) (! (= var_23 var_27))) (! (= var_23 var_28))) (! (= var_23 var_29))) (! (= var_23 var_31))) (! (= var_23 var_32))) (! (= var_23 var_33))) (! (= var_23 var_43))) (! (= var_23 var_53))) (! (= var_23 var_63))) (! (= var_23 var_73))) (! (= var_23 var_83))) (! (= var_23 var_93))) (! (= var_24 var_25))) (! (= var_24 var_26))) (! (= var_24 var_27))) (! (= var_24 var_28))) (! (= var_24 var_29))) (! (= var_24 var_34))) (! (= var_24 var_35))) (! (= var_24 var_36))) (! (= var_24 var_44))) (! (= var_24 var_54))) (! (= var_24 var_64))) (! (= var_24 var_74))) (! (= var_24 var_84))) (! (= var_24 var_94))) (! (= var_25 var_26))) (! (= var_25 var_27))) (! (= var_25 var_28))) (! (= var_25 var_29))) (! (= var_25 var_34))) (! (= var_25 var_35))) (! (= var_25 var_36))) (! (= var_25 var_45))) (! (= var_25 var_55))) (! (= var_25 var_65))) (! (= var_25 var_75))) (! (= var_25 var_85))) (! (= var_25 var_95))) (! (= var_26 var_27))) (! (= var_26 var_28))) (! (= var_26 var_29))) (! (= var_26 var_34))) (! (= var_26 var_35))) (! (= var_26 var_36))) (! (= var_26 var_46))) (! (= var_26 var_56))) (! (= var_26 var_66))) (! (= var_26 var_76))) (! (= var_26 var_86))) (! (= var_26 var_96))) (! (= var_27 var_28))) (! (= var_27 var_29))) (! (= var_27 var_37))) (! (= var_27 var_38))) (! (= var_27 var_39))) (! (= var_27 var_47))) (! (= var_27 var_57))) (! (= var_27 var_67))) (! (= var_27 var_77))) (! (= var_27 var_87))) (! (= var_27 var_97))) (! (= var_28 var_29))) (! (= var_28 var_37))) (! (= var_28 var_38))) (! (= var_28 var_39))) (! (= var_28 var_48))) (! (= var_28 var_58))) (! (= var_28 var_68))) (! (= var_28 var_78))) (! (= var_28 var_88))) (! (= var_28 var_98))) (! (= var_29 var_37))) (! (= var_29 var_38))) (! (= var_29 var_39))) (! (= var_29 var_49))) (! (= var_29 var_59))) (! (= var_29 var_69))) (! (= var_29 var_79))) (! (= var_29 var_89))) (! (= var_29 var_99))) (! (= var_31 var_32))) (! (= var_31 var_33))) (! (= var_31 var_34))) (! (= var_31 var_35))) (! (= var_31 var_36))) (! (= var_31 var_37))) (! (= var_31 var_38))) (! (= var_31 var_39))) (! (= var_31 var_41))) (! (= var_31 var_51))) (! (= var_31 var_61))) (! (= var_31 var_71))) (! (= var_31 var_81))) (! (= var_31 var_91))) (! (= var_32 var_33))) (! (= var_32 var_34))) (! (= var_32 var_35))) (! (= var_32 var_36))) (! (= var_32 var_37))) (! (= var_32 var_38))) (! (= var_32 var_39))) (! (= var_32 var_42))) (! (= var_32 var_52))) (! (= var_32 var_62))) (! (= var_32 var_72))) (! (= var_32 var_82))) (! (= var_32 var_92))) (! (= var_33 var_34))) (! (= var_33 var_35))) (! (= var_33 var_36))) (! (= var_33 var_37))) (! (= var_33 var_38))) (! (= var_33 var_39))) (! (= var_33 var_43))) (! (= var_33 var_53))) (! (= var_33 var_63))) (! (= var_33 var_73))) (! (= var_33 var_83))) (! (= var_33 var_93))) (! (= var_34 var_35))) (! (= var_34 var_36))) (! (= var_34 var_37))) (! (= var_34 var_38))) (! (= var_34 var_39))) (! (= var_34 var_44))) (! (= var_34 var_54))) (! (= var_34 var_64))) (! (= var_34 var_74))) (! (= var_34 var_84))) (! (= var_34 var_94))) (! (= var_35 var_36))) (! (= var_35 var_37))) (! (= var_35 var_38))) (! (= var_35 var_39))) (! (= var_35 var_45))) (! (= var_35 var_55))) (! (= var_35 var_65))) (! (= var_35 var_75))) (! (= var_35 var_85))) (! (= var_35 var_95))) (! (= var_36 var_37))) (! (= var_36 var_38))) (! (= var_36 var_39))) (! (= var_36 var_46))) (! (= var_36 var_56))) (! (= var_36 var_66))) (! (= var_36 var_76))) (! (= var_36 var_86))) (! (= var_36 var_96))) (! (= var_37 var_38))) (! (= var_37 var_39))) (! (= var_37 var_47))) (! (= var_37 var_57))) (! (= var_37 var_67))) (! (= var_37 var_77))) (! (= var_37 var_87))) (! (= var_37 var_97))) (! (= var_38 var_39))) (! (= var_38 var_48))) (! (= var_38 var_58))) (! (= var_38 var_68))) (! (= var_38 var_78))) (! (= var_38 var_88))) (! (= var_38 var_98))) (! (= var_39 var_49))) (! (= var_39 var_59))) (! (= var_39 var_69))) (! (= var_39 var_79))) (! (= var_39 var_89))) (! (= var_39 var_99))) (! (= var_41 var_42))) (! (= var_41 var_43))) (! (= var_41 var_44))) (! (= var_41 var_45))) (! (= var_41 var_46))) (! (= var_41 var_47))) (! (= var_41 var_48))) (! (= var_41 var_49))) (! (= var_41 var_51))) (! (= var_41 var_52))) (! (= var_41 var_53))) (! (= var_41 var_61))) (! (= var_41 var_62))) (! (= var_41 var_63))) (! (= var_41 var_71))) (! (= var_41 var_81))) (! (= var_41 var_91))) (! (= var_42 var_43))) (! (= var_42 var_44))) (! (= var_42 var_45))) (! (= var_42 var_46))) (! (= var_42 var_47))) (! (= var_42 var_48))) (! (= var_42 var_49))) (! (= var_42 var_51))) (! (= var_42 var_52))) (! (= var_42 var_53))) (! (= var_42 var_61))) (! (= var_42 var_62))) (! (= var_42 var_63))) (! (= var_42 var_72))) (! (= var_42 var_82))) (! (= var_42 var_92))) (! (= var_43 var_44))) (! (= var_43 var_45))) (! (= var_43 var_46))) (! (= var_43 var_47))) (! (= var_43 var_48))) (! (= var_43 var_49))) (! (= var_43 var_51))) (! (= var_43 var_52))) (! (= var_43 var_53))) (! (= var_43 var_61))) (! (= var_43 var_62))) (! (= var_43 var_63))) (! (= var_43 var_73))) (! (= var_43 var_83))) (! (= var_43 var_93))) (! (= var_44 var_45))) (! (= var_44 var_46))) (! (= var_44 var_47))) (! (= var_44 var_48))) (! (= var_44 var_49))) (! (= var_44 var_54))) (! (= var_44 var_55))) (! (= var_44 var_56))) (! (= var_44 var_64))) (! (= var_44 var_65))) (! (= var_44 var_66))) (! (= var_44 var_74))) (! (= var_44 var_84))) (! (= var_44 var_94))) (! (= var_45 var_46))) (! (= var_45 var_47))) (! (= var_45 var_48))) (! (= var_45 var_49))) (! (= var_45 var_54))) (! (= var_45 var_55))) (! (= var_45 var_56))) (! (= var_45 var_64))) (! (= var_45 var_65))) (! (= var_45 var_66))) (! (= var_45 var_75))) (! (= var_45 var_85))) (! (= var_45 var_95))) (! (= var_46 var_47))) (! (= var_46 var_48))) (! (= var_46 var_49))) (! (= var_46 var_54))) (! (= var_46 var_55))) (! (= var_46 var_56))) (! (= var_46 var_64))) (! (= var_46 var_65))) (! (= var_46 var_66))) (! (= var_46 var_76))) (! (= var_46 var_86))) (! (= var_46 var_96))) (! (= var_47 var_48))) (! (= var_47 var_49))) (! (= var_47 var_57))) (! (= var_47 var_58))) (! (= var_47 var_59))) (! (= var_47 var_67))) (! (= var_47 var_68))) (! (= var_47 var_69))) (! (= var_47 var_77))) (! (= var_47 var_87))) (! (= var_47 var_97))) (! (= var_48 var_49))) (! (= var_48 var_57))) (! (= var_48 var_58))) (! (= var_48 var_59))) (! (= var_48 var_67))) (! (= var_48 var_68))) (! (= var_48 var_69))) (! (= var_48 var_78))) (! (= var_48 var_88))) (! (= var_48 var_98))) (! (= var_49 var_57))) (! (= var_49 var_58))) (! (= var_49 var_59))) (! (= var_49 var_67))) (! (= var_49 var_68))) (! (= var_49 var_69))) (! (= var_49 var_79))) (! (= var_49 var_89))) (! (= var_49 var_99))) (! (= var_51 var_52))) (! (= var_51 var_53))) (! (= var_51 var_54))) (! (= var_51 var_55))) (! (= var_51 var_56))) (! (= var_51 var_57))) (! (= var_51 var_58))) (! (= var_51 var_59))) (! (= var_51 var_61))) (! (= var_51 var_62))) (! (= var_51 var_63))) (! (= var_51 var_71))) (! (= var_51 var_81))) (! (= var_51 var_91))) (! (= var_52 var_53))) (! (= var_52 var_54))) (! (= var_52 var_55))) (! (= var_52 var_56))) (! (= var_52 var_57))) (! (= var_52 var_58))) (! (= var_52 var_59))) (! (= var_52 var_61))) (! (= var_52 var_62))) (! (= var_52 var_63))) (! (= var_52 var_72))) (! (= var_52 var_82))) (! (= var_52 var_92))) (! (= var_53 var_54))) (! (= var_53 var_55))) (! (= var_53 var_56))) (! (= var_53 var_57))) (! (= var_53 var_58))) (! (= var_53 var_59))) (! (= var_53 var_61))) (! (= var_53 var_62))) (! (= var_53 var_63))) (! (= var_53 var_73))) (! (= var_53 var_83))) (! (= var_53 var_93))) (! (= var_54 var_55))) (! (= var_54 var_56))) (! (= var_54 var_57))) (! (= var_54 var_58))) (! (= var_54 var_59))) (! (= var_54 var_64))) (! (= var_54 var_65))) (! (= var_54 var_66))) (! (= var_54 var_74))) (! (= var_54 var_84))) (! (= var_54 var_94))) (! (= var_55 var_56))) (! (= var_55 var_57))) (! (= var_55 var_58))) (! (= var_55 var_59))) (! (= var_55 var_64))) (! (= var_55 var_65))) (! (= var_55 var_66))) (! (= var_55 var_75))) (! (= var_55 var_85))) (! (= var_55 var_95))) (! (= var_56 var_57))) (! (= var_56 var_58))) (! (= var_56 var_59))) (! (= var_56 var_64))) (! (= var_56 var_65))) (! (= var_56 var_66))) (! (= var_56 var_76))) (! (= var_56 var_86))) (! (= var_56 var_96))) (! (= var_57 var_58))) (! (= var_57 var_59))) (! (= var_57 var_67))) (! (= var_57 var_68))) (! (= var_57 var_69))) (! (= var_57 var_77))) (! (= var_57 var_87))) (! (= var_57 var_97))) (! (= var_58 var_59))) (! (= var_58 var_67))) (! (= var_58 var_68))) (! (= var_58 var_69))) (! (= var_58 var_78))) (! (= var_58 var_88))) (! (= var_58 var_98))) (! (= var_59 var_67))) (! (= var_59 var_68))) (! (= var_59 var_69))) (! (= var_59 var_79))) (! (= var_59 var_89))) (! (= var_59 var_99))) (! (= var_61 var_62))) (! (= var_61 var_63))) (! (= var_61 var_64))) (! (= var_61 var_65))) (! (= var_61 var_66))) (! (= var_61 var_67))) (! (= var_61 var_68))) (! (= var_61 var_69))) (! (= var_61 var_71))) (! (= var_61 var_81))) (! (= var_61 var_91))) (! (= var_62 var_63))) (! (= var_62 var_64))) (! (= var_62 var_65))) (! (= var_62 var_66))) (! (= var_62 var_67))) (! (= var_62 var_68))) (! (= var_62 var_69))) (! (= var_62 var_72))) (! (= var_62 var_82))) (! (= var_62 var_92))) (! (= var_63 var_64))) (! (= var_63 var_65))) (! (= var_63 var_66))) (! (= var_63 var_67))) (! (= var_63 var_68))) (! (= var_63 var_69))) (! (= var_63 var_73))) (! (= var_63 var_83))) (! (= var_63 var_93))) (! (= var_64 var_65))) (! (= var_64 var_66))) (! (= var_64 var_67))) (! (= var_64 var_68))) (! (= var_64 var_69))) (! (= var_64 var_74))) (! (= var_64 var_84))) (! (= var_64 var_94))) (! (= var_65 var_66))) (! (= var_65 var_67))) (! (= var_65 var_68))) (! (= var_65 var_69))) (! (= var_65 var_75))) (! (= var_65 var_85))) (! (= var_65 var_95))) (! (= var_66 var_67))) (! (= var_66 var_68))) (! (= var_66 var_69))) (! (= var_66 var_76))) (! (= var_66 var_86))) (! (= var_66 var_96))) (! (= var_67 var_68))) (! (= var_67 var_69))) (! (= var_67 var_77))) (! (= var_67 var_87))) (! (= var_67 var_97))) (! (= var_68 var_69))) (! (= var_68 var_78))) (! (= var_68 var_88))) (! (= var_68 var_98))) (! (= var_69 var_79))) (! (= var_69 var_89))) (! (= var_69 var_99))) (! (= var_71 var_72))) (! (= var_71 var_73))) (! (= var_71 var_74))) (! (= var_71 var_75))) (! (= var_71 var_76))) (! (= var_71 var_77))) (! (= var_71 var_78))) (! (= var_71 var_79))) (! (= var_71 var_81))) (! (= var_71 var_82))) (! (= var_71 var_83))) (! (= var_71 var_91))) (! (= var_71 var_92))) (! (= var_71 var_93))) (! (= var_72 var_73))) (! (= var_72 var_74))) (! (= var_72 var_75))) (! (= var_72 var_76))) (! (= var_72 var_77))) (! (= var_72 var_78))) (! (= var_72 var_79))) (! (= var_72 var_81))) (! (= var_72 var_82))) (! (= var_72 var_83))) (! (= var_72 var_91))) (! (= var_72 var_92))) (! (= var_72 var_93))) (! (= var_73 var_74))) (! (= var_73 var_75))) (! (= var_73 var_76))) (! (= var_73 var_77))) (! (= var_73 var_78))) (! (= var_73 var_79))) (! (= var_73 var_81))) (! (= var_73 var_82))) (! (= var_73 var_83))) (! (= var_73 var_91))) (! (= var_73 var_92))) (! (= var_73 var_93))) (! (= var_74 var_75))) (! (= var_74 var_76))) (! (= var_74 var_77))) (! (= var_74 var_78))) (! (= var_74 var_79))) (! (= var_74 var_84))) (! (= var_74 var_85))) (! (= var_74 var_86))) (! (= var_74 var_94))) (! (= var_74 var_95))) (! (= var_74 var_96))) (! (= var_75 var_76))) (! (= var_75 var_77))) (! (= var_75 var_78))) (! (= var_75 var_79))) (! (= var_75 var_84))) (! (= var_75 var_85))) (! (= var_75 var_86))) (! (= var_75 var_94))) (! (= var_75 var_95))) (! (= var_75 var_96))) (! (= var_76 var_77))) (! (= var_76 var_78))) (! (= var_76 var_79))) (! (= var_76 var_84))) (! (= var_76 var_85))) (! (= var_76 var_86))) (! (= var_76 var_94))) (! (= var_76 var_95))) (! (= var_76 var_96))) (! (= var_77 var_78))) (! (= var_77 var_79))) (! (= var_77 var_87))) (! (= var_77 var_88))) (! (= var_77 var_89))) (! (= var_77 var_97))) (! (= var_77 var_98))) (! (= var_77 var_99))) (! (= var_78 var_79))) (! (= var_78 var_87))) (! (= var_78 var_88))) (! (= var_78 var_89))) (! (= var_78 var_97))) (! (= var_78 var_98))) (! (= var_78 var_99))) (! (= var_79 var_87))) (! (= var_79 var_88))) (! (= var_79 var_89))) (! (= var_79 var_97))) (! (= var_79 var_98))) (! (= var_79 var_99))) (! (= var_81 var_82))) (! (= var_81 var_83))) (! (= var_81 var_84))) (! (= var_81 var_85))) (! (= var_81 var_86))) (! (= var_81 var_87))) (! (= var_81 var_88))) (! (= var_81 var_89))) (! (= var_81 var_91))) (! (= var_81 var_92))) (! (= var_81 var_93))) (! (= var_82 var_83))) (! (= var_82 var_84))) (! (= var_82 var_85))) (! (= var_82 var_86))) (! (= var_82 var_87))) (! (= var_82 var_88))) (! (= var_82 var_89))) (! (= var_82 var_91))) (! (= var_82 var_92))) (! (= var_82 var_93))) (! (= var_83 var_84))) (! (= var_83 var_85))) (! (= var_83 var_86))) (! (= var_83 var_87))) (! (= var_83 var_88))) (! (= var_83 var_89))) (! (= var_83 var_91))) (! (= var_83 var_92))) (! (= var_83 var_93))) (! (= var_84 var_85))) (! (= var_84 var_86))) (! (= var_84 var_87))) (! (= var_84 var_88))) (! (= var_84 var_89))) (! (= var_84 var_94))) (! (= var_84 var_95))) (! (= var_84 var_96))) (! (= var_85 var_86))) (! (= var_85 var_87))) (! (= var_85 var_88))) (! (= var_85 var_89))) (! (= var_85 var_94))) (! (= var_85 var_95))) (! (= var_85 var_96))) (! (= var_86 var_87))) (! (= var_86 var_88))) (! (= var_86 var_89))) (! (= var_86 var_94))) (! (= var_86 var_95))) (! (= var_86 var_96))) (! (= var_87 var_88))) (! (= var_87 var_89))) (! (= var_87 var_97))) (! (= var_87 var_98))) (! (= var_87 var_99))) (! (= var_88 var_89))) (! (= var_88 var_97))) (! (= var_88 var_98))) (! (= var_88 var_99))) (! (= var_89 var_97))) (! (= var_89 var_98))) (! (= var_89 var_99))) (! (= var_91 var_92))) (! (= var_91 var_93))) (! (= var_91 var_94))) (! (= var_91 var_95))) (! (= var_91 var_96))) (! (= var_91 var_97))) (! (= var_91 var_98))) (! (= var_91 var_99))) (! (= var_92 var_93))) (! (= var_92 var_94))) (! (= var_92 var_95))) (! (= var_92 var_96))) (! (= var_92 var_97))) (! (= var_92 var_98))) (! (= var_92 var_99))) (! (= var_93 var_94))) (! (= var_93 var_95))) (! (= var_93 var_96))) (! (= var_93 var_97))) (! (= var_93 var_98))) (! (= var_93 var_99))) (! (= var_94 var_95))) (! (= var_94 var_96))) (! (= var_94 var_97))) (! (= var_94 var_98))) (! (= var_94 var_99))) (! (= var_95 var_96))) (! (= var_95 var_97))) (! (= var_95 var_98))) (! (= var_95 var_99))) (! (= var_96 var_97))) (! (= var_96 var_98))) (! (= var_96 var_99))) (! (= var_97 var_98))) (! (= var_97 var_99))) (! (= var_98 var_99))) (= var_12 6)) (= var_13 4)) (= var_17 7)) (= var_25 2)) (= var_28 3)) (= var_29 6)) (= var_33 1)) (= var_41 2)) (= var_42 3)) (= var_45 8)) (= var_54 7)) (= var_57 1)) (= var_59 4)) (= var_71 9)) (= var_81 8)) (= var_88 2)) (= var_94 4))"

from z3 import *

# vs = [Bool("var_%d" % i) for i in range(1, 41)]
# vs = [Bool("var_%d" % i) for i in range(1, 51)]
vs = {i: Int("var_%d" % i) for i in range(10, 100) if i % 10 != 0}
print(len(vs))
i = 0
def parse():
    global i
    if expr[i] == '(':
        i += 1
        if expr[i] == '=':
            i += 2
            a = parse()
            i += 1
            b = parse()
            assert expr[i] == ')'
            i += 1
            return a == b
        if expr[i] == '|':
            i += 2
            a = parse()
            i += 1
            b = parse()
            assert expr[i] == ')'
            i += 1
            return Or(a, b)
        elif expr[i] == '&':
            i += 2
            a = parse()
            i += 1
            b = parse()
            assert expr[i] == ')'
            i += 1
            return And(a, b)
        elif expr[i] == '!':
            i += 2
            a = parse()
            assert expr[i] == ')'
            i += 1
            return Not(a)
        else:
            assert False
    elif expr[i:i+4] == "var_":
        i += 4
        j = i
        while expr[j].isdigit():
            j += 1
        idx = int(expr[i:j])
        i = j
        return vs[idx]
    else:
        j = i
        while expr[j].isdigit():
            j += 1
        assert i < j
        ret = int(expr[i:j])
        i = j
        return ret
expr = parse()
for _, v in vs.items():
    expr = And(expr, v >= 1, v <= 9)
s = Solver()
s.add(expr)
# print(s.check())
assert s.check() == sat
# m = s.model()
# ans = 0
# ar = []
# def rec(i, expr, ans):
#     if i == len(vs):
#         ar.append(ans)
#         return
#     s = Solver()
#     s.add(expr)
#     s.add(Not(vs[i]))
#     c1 = s.check()
#     if c1 == sat:
#         rec(i + 1, And(expr, Not(vs[i])), ans)
#     s = Solver()
#     s.add(expr)
#     s.add(vs[i])
#     c2 = s.check()
#     if c2 == sat:
#         rec(i + 1, And(expr, vs[i]), ans | (1 << i))
# rec(0, expr, 0)

# for i in reversed(range(len(vs))):
#     s = Solver()
#     s.add(expr)
#     s.add(Not(vs[i]))
#     c1 = s.check()
#     if c1 != sat:
#         ans |= 1 << i
#         expr = And(expr, vs[i])
#     else:
#         expr = And(expr, Not(vs[i]))

ans = 0
for i in sorted(vs.keys()):
    c = 1
    while c <= 9:
        s = Solver()
        s.add(expr)
        s.add(vs[i] == c)
        if s.check() == sat:
            break
        c += 1
    assert c <= 9
    print(i, c)
    ans = ans * 9 + (c - 1)
    expr = And(expr, vs[i] == c)
print(ans)
# Out:
# 81
# 11 5
# 12 6
# 13 4
# 14 8
# 15 9
# 16 3
# 17 7
# 18 1
# 19 2
# 21 7
# 22 8
# 23 9
# 24 5
# 25 2
# 26 1
# 27 4
# 28 3
# 29 6
# 31 3
# 32 2
# 33 1
# 34 6
# 35 4
# 36 7
# 37 8
# 38 5
# 39 9
# 41 2
# 42 3
# 43 7
# 44 1
# 45 8
# 46 4
# 47 6
# 48 9
# 49 5
# 51 6
# 52 9
# 53 5
# 54 7
# 55 3
# 56 2
# 57 1
# 58 8
# 59 4
# 61 4
# 62 1
# 63 8
# 64 9
# 65 5
# 66 6
# 67 2
# 68 7
# 69 3
# 71 9
# 72 7
# 73 3
# 74 2
# 75 6
# 76 8
# 77 5
# 78 4
# 79 1
# 81 8
# 82 4
# 83 6
# 84 3
# 85 1
# 86 5
# 87 9
# 88 2
# 89 7
# 91 1
# 92 5
# 93 2
# 94 4
# 95 7
# 96 9
# 97 3
# 98 6
# 99 8
# 100573847453233330105890470844482405072957615231969369459908387717689164043268

# %%
s.model()
# Out:
# [var_84 = 1,
#  var_15 = 6,
#  var_29 = 7,
#  var_76 = 9,
#  var_23 = 5,
#  var_85 = 2,
#  var_86 = 3,
#  var_83 = 9,
#  var_22 = 3,
#  var_13 = 4,
#  var_92 = 2,
#  var_47 = 8,
#  var_12 = 1,
#  var_16 = 7,
#  var_18 = 3,
#  var_97 = 7,
#  var_91 = 1,
#  var_35 = 3,
#  var_38 = 4,
#  var_89 = 6,
#  var_25 = 1,
#  var_42 = 6,
#  var_26 = 4,
#  var_81 = 7,
#  var_14 = 5,
#  var_95 = 5,
#  var_82 = 8,
#  var_34 = 2,
#  var_65 = 4,
#  var_24 = 9,
#  var_28 = 6,
#  var_46 = 2,
#  var_57 = 6,
#  var_11 = 2,
#  var_59 = 5,
#  var_74 = 7,
#  var_62 = 7,
#  var_69 = 2,
#  var_49 = 4,
#  var_75 = 8,
#  var_45 = 7,
#  var_58 = 7,
#  var_31 = 6,
#  var_66 = 5,
#  var_17 = 9,
#  var_19 = 8,
#  var_32 = 9,
#  var_33 = 7,
#  var_21 = 8,
#  var_63 = 8,
#  var_67 = 3,
#  var_68 = 1,
#  var_77 = 1,
#  var_72 = 5,
#  var_56 = 1,
#  var_96 = 6,
#  var_27 = 2,
#  var_44 = 3,
#  var_71 = 4,
#  var_39 = 1,
#  var_52 = 4,
#  var_36 = 8,
#  var_51 = 3,
#  var_94 = 4,
#  var_54 = 8,
#  var_88 = 5,
# ...
